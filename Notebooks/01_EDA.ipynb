# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Documents\PGA 30\Machine Learning\Machine Learning Project\Linear Regression Project\Medical_Cost_Prediction.csv")
df
# Out:
#       age     sex   bmi smoking_status alcohol_use diabetes heart_disease  \
# 0      44    male  19.8     non-smoker         yes       no            no
# 1      57  female  27.7     non-smoker          no       no            no
# 2      22  female  28.8     non-smoker          no       no            no
# 3      34  female  23.7         smoker         yes       no            no
# 4      43  female  22.8     non-smoker          no       no            no
# ...   ...     ...   ...            ...         ...      ...           ...
# 9995   18    male  32.2         smoker         yes       no            no
# 9996   29  female  25.6     non-smoker          no       no            no
# 9997   34  female  24.8     non-smoker          no       no            no
# 9998   41    male  28.9     non-smoker         yes       no            no
# 9999   36  female  32.9     non-smoker         yes       no            no
#
#       blood_pressure  cholesterol physical_activity_level  hospital_visits  \
# ...

# %%
df.isnull().sum()
# Out:
# age                          0
# sex                          0
# bmi                        496
# smoking_status               0
# alcohol_use                  0
# diabetes                     0
# heart_disease                0
# blood_pressure             789
# cholesterol                300
# physical_activity_level    600
# hospital_visits              0
# medications                  0
# medical_cost                 0
# dtype: int64

# %%
df['bmi'] = df['bmi'].fillna(
    df.groupby(['sex', 'smoking_status'])['bmi']
      .transform(lambda x: x.mode()[0]))

# %%
df.isnull().sum()
# Out:
# age                          0
# sex                          0
# bmi                          0
# smoking_status               0
# alcohol_use                  0
# diabetes                     0
# heart_disease                0
# blood_pressure             789
# cholesterol                300
# physical_activity_level    600
# hospital_visits              0
# medications                  0
# medical_cost                 0
# dtype: int64

# %%
df['blood_pressure'] = df['blood_pressure'].fillna(
    df.groupby(['age','diabetes','heart_disease'])['blood_pressure'].transform('median'))

# %%
df.isnull().sum()
# Out:
# age                          0
# sex                          0
# bmi                          0
# smoking_status               0
# alcohol_use                  0
# diabetes                     0
# heart_disease                0
# blood_pressure               2
# cholesterol                300
# physical_activity_level    600
# hospital_visits              0
# medications                  0
# medical_cost                 0
# dtype: int64

# %%
df['physical_activity_level'] = df['physical_activity_level'].fillna(
    df.groupby(['age','sex'])['physical_activity_level'].transform(lambda x: x.mode()[0]))

# %%
df.isnull().sum()
# Out:
# age                          0
# sex                          0
# bmi                          0
# smoking_status               0
# alcohol_use                  0
# diabetes                     0
# heart_disease                0
# blood_pressure               2
# cholesterol                300
# physical_activity_level      0
# hospital_visits              0
# medications                  0
# medical_cost                 0
# dtype: int64

# %%
df['cholesterol'] = df['cholesterol'].fillna(
    df.groupby(['sex','physical_activity_level'])['cholesterol'].transform('median'))

# %%
df.isnull().sum()
# Out:
# age                        0
# sex                        0
# bmi                        0
# smoking_status             0
# alcohol_use                0
# diabetes                   0
# heart_disease              0
# blood_pressure             2
# cholesterol                0
# physical_activity_level    0
# hospital_visits            0
# medications                0
# medical_cost               0
# dtype: int64

# %%
df['blood_pressure'] = df['blood_pressure'].fillna(df['blood_pressure'].median())

# %% [markdown]
# ## Graph 1 :- Gender Distribution

# %%
plt.figure(figsize=(10,5))
df['sex'].value_counts().plot(kind='pie', autopct='%1.1f%%', shadow=True, colors = ["#FF9999", "#CC0000"])
plt.title("Gender Percentage")
plt.show()

# %% [raw]
# Inference :- The dataset shows an almost equal distribution of males and females, indicating no gender bias. A balanced gender split ensures fair                    analysis across demographic groups.
#
# Solutions :- No corrective action needed. The dataset is already balanced and suitable for demographic comparison.

# %% [markdown]
# ## Graph 2:- Smoking Status by Gender

# %%
plt.figure(figsize=(10,6))
sns.countplot(data=df, x="sex", hue='smoking_status', palette = "plasma")
plt.title("Smoking Status by Gender")
plt.xticks(rotation=45)
plt.show()

# %% [raw]
# Inference :- Non-smokers dominate in both genders especially among females. Males have  comparatively higher proportion of smokers, which aligns with                real-world trends.
#
# Solutions :- Because smoking is higher in males, gender should be treated as a contributing risk factor. Future modeling should include both gender and              smoking to correctly capture their impact on health outcomes.

# %% [markdown]
# ## Graph 3 :- BMI distribution by Gender

# %%
plt.figure(figsize=(8,5))
sns.violinplot(data=df, x='sex', y='bmi', palette="Set2")
plt.title("BMI Distribution by Sex")
plt.show()

# %% [raw]
# Inference :- Both genders show similar BMI distributions, although males have slightly higher variability. The median BMI is almost the same for males               and females.

# %% [markdown]
# ## Graph 4 :- Which gender has higher medical cost

# %%
sns.barplot(x='sex', y='medical_cost', data=df, ci=95 , palette="Dark2")
plt.title("Average Medical Cost by Smoking Status")
plt.show()

# %% [raw]
# Inference :- Male patients tend to have higher average medical costs compared to females. This may be linked to higher smoking rates, blood pressure,                or lifestyle differences.
#
# Solutions :- Male patients may face higher medical expenses, possibly due to lifestyle risks. Early health checkups and preventive care can help reduce             costly treatments in the future.

# %% [markdown]
# ## Graph 5 :- Blood pressure with Medical cost

# %%
sns.scatterplot(x='blood_pressure', y='medical_cost', hue='sex', data=df)
plt.title("Blood Pressure vs Medical Cost")
plt.show()

# %% [raw]
# Inference :- There is clear upward trend where medical cost increases with rising blood pressure. High blood pressure patients frequently incur                      higher expenses.
#
# Solutions :- Higher blood pressure strongly increases medical cost. Patients should monitor BP regularly, reduce salt intake, maintain physical                      activity, and follow prescribed hypertension treatments to avoid complications.

# %% [markdown]
# ## Graph 6 :- Blood pressure with gender

# %%
sns.barplot(x='sex', y='blood_pressure', data=df, ci=95, palette="muted")
plt.title("Average Blood Pressure by Sex")
plt.show()

# %% [raw]
# Inference :- Both males and females have nearly the same average blood pressure, showing no significant gender-based variation in BP levels.
#
# Solutions :- Both genders show similar blood pressure levels, meaning hypertension prevention should be recommended to all patients. Encouraging                     regular BP checkups for everyone is important.

# %% [markdown]
# ## Graph 7 :- Male vs Diabetes

# %%
pd.crosstab(df['sex'], df['diabetes'])
# Out:
# diabetes    no  yes
# sex
# female    4480  682
# male      4188  650

# %%
pd.crosstab(df['sex'], df['diabetes']).plot(kind='bar', figsize=(6,4), color=["skyblue", "salmon"])
plt.title("Sex vs Diabetes")
plt.ylabel("Count")
plt.show()

# %% [raw]
# Inference :- Diabetes prevalence is similar across both genders, and most individuals are non-diabetic. This indicates a relatively healthy population               in the dataset
#
# Solutions :- Diabetes affects males and females equally, so awareness programs about sugar control, diet management, and regular glucose monitoring                  should target all adults equally.

# %% [markdown]
# ## Graph 8 :- Smoking status with Heart Diseases

# %%
pd.crosstab(df['smoking_status'], df['heart_disease'])
# Out:
# heart_disease     no  yes
# smoking_status
# non-smoker      7476  550
# smoker          1734  240

# %%
pd.crosstab(df['smoking_status'], df['heart_disease']).plot(kind='bar',color=["#008080", "#FFA500"] )
plt.title("Smoking Status vs Heart Disease")
plt.show()

# %% [raw]
# Inference :- Smokers show a noticeably higher count of heart disease cases compared to non-smokers. This reflects a strong and expected medical                      correlation.
#
# Solutions :- Smokers have a much higher risk of heart disease. Patients who smoke should be strongly advised to quit and get regular heart checkups, as              early intervention can prevent severe cardiac issues.

# %% [markdown]
# ## Graph 9 :- Correlation Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %% [raw]
# Inference :- Age and blood pressure have the strongest correlation (0.68) meaning BP tends to rise with age. Medical cost is most strongly correlated                with hospital visits (0.56), age (0.44), and blood pressure (0.38).BMI shows very weak correlation with most variables  meaning BMI alone               does not strongly determine risk or cost in this dataset.
#
# Solutions :- Since rising age is strongly linked with higher blood pressure, patients especially older adults should monitor BP regularly and adopt                  heart healthy habits. Higher medical costs being linked to hospital visits, BP and age means patients should prioritize preventive care,                early treatment, and routine checkups to avoid expensive complications.
