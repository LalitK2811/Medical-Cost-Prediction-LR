# %%
import pandas as pd
import numpy as np 

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r"C:\Users\Lenovo\Documents\PGA 30\Machine Learning\Machine Learning Project\Linear Regression Project\Medical_Cost_Prediction.csv")
df
# Out:
#       age     sex   bmi smoking_status alcohol_use diabetes heart_disease  \
# 0      44    male  19.8     non-smoker         yes       no            no
# 1      57  female  27.7     non-smoker          no       no            no
# 2      22  female  28.8     non-smoker          no       no            no
# 3      34  female  23.7         smoker         yes       no            no
# 4      43  female  22.8     non-smoker          no       no            no
# ...   ...     ...   ...            ...         ...      ...           ...
# 9995   18    male  32.2         smoker         yes       no            no
# 9996   29  female  25.6     non-smoker          no       no            no
# 9997   34  female  24.8     non-smoker          no       no            no
# 9998   41    male  28.9     non-smoker         yes       no            no
# 9999   36  female  32.9     non-smoker         yes       no            no
#
#       blood_pressure  cholesterol physical_activity_level  hospital_visits  \
# 0              123.0        178.0                    high                0
# 1              123.0        183.0                moderate                2
# 2              128.0        140.0                     low                0
# 3                NaN        175.0                moderate                1
# 4              113.0        159.0                    high                1
# ...              ...          ...                     ...              ...
# 9995           101.0        157.0                     low                1
# 9996           121.0        123.0                moderate                0
# 9997           112.0        156.0                    high                0
# 9998            97.0        134.0                     low                1
# 9999           110.0        136.0                    high                0
#
#       medications  medical_cost
# 0               0       3714.78
# 1               0       4713.37
# 2               0       3802.24
# 3               1       9761.02
# 4               0       2768.39
# ...           ...           ...
# 9995            0      10556.39
# 9996            0        200.00
# 9997            1       1289.51
# 9998            0       5550.76
# 9999            0        200.00
#
# [10000 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# age                          0
# sex                          0
# bmi                        496
# smoking_status               0
# alcohol_use                  0
# diabetes                     0
# heart_disease                0
# blood_pressure             789
# cholesterol                300
# physical_activity_level    600
# hospital_visits              0
# medications                  0
# medical_cost                 0
# dtype: int64

# %%
df['bmi'] = df['bmi'].fillna(
    df.groupby(['sex', 'smoking_status'])['bmi']
      .transform(lambda x: x.mode()[0]))

# %%
df.isnull().sum()
# Out:
# age                          0
# sex                          0
# bmi                          0
# smoking_status               0
# alcohol_use                  0
# diabetes                     0
# heart_disease                0
# blood_pressure             789
# cholesterol                300
# physical_activity_level    600
# hospital_visits              0
# medications                  0
# medical_cost                 0
# dtype: int64

# %%
df['blood_pressure'] = df['blood_pressure'].fillna(
    df.groupby(['age','diabetes','heart_disease'])['blood_pressure'].transform('median'))

# %%
df.isnull().sum()
# Out:
# age                          0
# sex                          0
# bmi                          0
# smoking_status               0
# alcohol_use                  0
# diabetes                     0
# heart_disease                0
# blood_pressure               2
# cholesterol                300
# physical_activity_level    600
# hospital_visits              0
# medications                  0
# medical_cost                 0
# dtype: int64

# %%
df['physical_activity_level'] = df['physical_activity_level'].fillna(
    df.groupby(['age','sex'])['physical_activity_level'].transform(lambda x: x.mode()[0]))

# %%
df.isnull().sum()
# Out:
# age                          0
# sex                          0
# bmi                          0
# smoking_status               0
# alcohol_use                  0
# diabetes                     0
# heart_disease                0
# blood_pressure               2
# cholesterol                300
# physical_activity_level      0
# hospital_visits              0
# medications                  0
# medical_cost                 0
# dtype: int64

# %%
df['cholesterol'] = df['cholesterol'].fillna(
    df.groupby(['sex','physical_activity_level'])['cholesterol'].transform('median'))

# %%
df.isnull().sum()
# Out:
# age                        0
# sex                        0
# bmi                        0
# smoking_status             0
# alcohol_use                0
# diabetes                   0
# heart_disease              0
# blood_pressure             2
# cholesterol                0
# physical_activity_level    0
# hospital_visits            0
# medications                0
# medical_cost               0
# dtype: int64

# %%
df['blood_pressure'] = df['blood_pressure'].fillna(df['blood_pressure'].median())

# %% [markdown]
# # Linear Regression Model

# %%
x = df.drop(columns=['medical_cost'])   
y = df['medical_cost']

# %%
x
# Out:
#       age     sex   bmi smoking_status alcohol_use diabetes heart_disease  \
# 0      44    male  19.8     non-smoker         yes       no            no
# 1      57  female  27.7     non-smoker          no       no            no
# 2      22  female  28.8     non-smoker          no       no            no
# 3      34  female  23.7         smoker         yes       no            no
# 4      43  female  22.8     non-smoker          no       no            no
# ...   ...     ...   ...            ...         ...      ...           ...
# 9995   18    male  32.2         smoker         yes       no            no
# 9996   29  female  25.6     non-smoker          no       no            no
# 9997   34  female  24.8     non-smoker          no       no            no
# 9998   41    male  28.9     non-smoker         yes       no            no
# 9999   36  female  32.9     non-smoker         yes       no            no
#
#       blood_pressure  cholesterol physical_activity_level  hospital_visits  \
# 0              123.0        178.0                    high                0
# 1              123.0        183.0                moderate                2
# 2              128.0        140.0                     low                0
# 3              112.0        175.0                moderate                1
# 4              113.0        159.0                    high                1
# ...              ...          ...                     ...              ...
# 9995           101.0        157.0                     low                1
# 9996           121.0        123.0                moderate                0
# 9997           112.0        156.0                    high                0
# 9998            97.0        134.0                     low                1
# 9999           110.0        136.0                    high                0
#
#       medications
# 0               0
# 1               0
# 2               0
# 3               1
# 4               0
# ...           ...
# 9995            0
# 9996            0
# 9997            1
# 9998            0
# 9999            0
#
# [10000 rows x 12 columns]

# %%
x = pd.get_dummies(x, drop_first=True)

# %%
x
# Out:
#       age   bmi  blood_pressure  cholesterol  hospital_visits  medications  \
# 0      44  19.8           123.0        178.0                0            0
# 1      57  27.7           123.0        183.0                2            0
# 2      22  28.8           128.0        140.0                0            0
# 3      34  23.7           112.0        175.0                1            1
# 4      43  22.8           113.0        159.0                1            0
# ...   ...   ...             ...          ...              ...          ...
# 9995   18  32.2           101.0        157.0                1            0
# 9996   29  25.6           121.0        123.0                0            0
# 9997   34  24.8           112.0        156.0                0            1
# 9998   41  28.9            97.0        134.0                1            0
# 9999   36  32.9           110.0        136.0                0            0
#
#       sex_male  smoking_status_smoker  alcohol_use_yes  diabetes_yes  \
# 0         True                  False             True         False
# 1        False                  False            False         False
# 2        False                  False            False         False
# 3        False                   True             True         False
# 4        False                  False            False         False
# ...        ...                    ...              ...           ...
# 9995      True                   True             True         False
# 9996     False                  False            False         False
# 9997     False                  False            False         False
# 9998      True                  False             True         False
# 9999     False                  False             True         False
#
#       heart_disease_yes  physical_activity_level_low  \
# 0                 False                        False
# 1                 False                        False
# 2                 False                         True
# 3                 False                        False
# 4                 False                        False
# ...                 ...                          ...
# 9995              False                         True
# 9996              False                        False
# 9997              False                        False
# 9998              False                         True
# 9999              False                        False
#
#       physical_activity_level_moderate
# 0                                False
# 1                                 True
# 2                                False
# 3                                 True
# 4                                False
# ...                                ...
# 9995                             False
# 9996                              True
# 9997                             False
# 9998                             False
# 9999                             False
#
# [10000 rows x 13 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, train_size=0.8, random_state = 48)

# %%
scale = StandardScaler()

# %%
x_train_scale = scale.fit_transform(x_train)
x_test_scale = scale.transform(x_test)

# %%
LR = LinearRegression()

# %%
LR.fit(x_train_scale, y_train)
# Out:
# LinearRegression()

# %%
y_predict = LR.predict(x_test_scale)

# %%
r2 = r2_score(y_test, y_predict)
r2*100
# Out:
# 90.0373293245108

# %%
mae = mean_absolute_error(y_test, y_predict)
mse = mean_squared_error(y_test, y_predict)
rmse = np.sqrt(mse)

# %%
mae
# Out:
# 1540.0977718243294

# %%
mse
# Out:
# 3688553.5041921274

# %%
rmse
# Out:
# np.float64(1920.5607265046651)

# %% [markdown]
# # Test model

# %%
data = pd.DataFrame([
    {'age' : 25,
     'bmi' : 30.0 ,
     'blood_pressure' : 132,
     'cholesterol' : 170,
     'hospital_visits' : 2,
     'medications' : 1,
     'sex_male' : 1,
     'smoking_status_smoker' : 0,
     'alcohol_use_yes' : 1,
      'diabetes_yes' : 0,
     'heart_disease_yes' : 1,
     'physical_activity_level_low' : 0,
       'physical_activity_level_moderate' : 1}
    ])

# %%
predicted = LR.predict(data)
predicted
# Out:
# array([137038.29271974])

# %% [markdown]
# # Lasso ( L1 )

# %%
from sklearn.linear_model import Lasso , Ridge, ElasticNet

# %%
lasso = Lasso()

# %%
lasso.fit(x_train_scale, y_train)
# Out:
# Lasso()

# %%
y_pred_lasso = lasso.predict(x_test_scale)

# %%
r2_lasso = r2_score(y_test, y_pred_lasso)
r2_lasso*100
# Out:
# 90.03776671398673

# %% [markdown]
# # Ridge ( L2 )

# %%
ridge = Ridge()

# %%
ridge.fit(x_train_scale, y_train)
# Out:
# Ridge()

# %%
y_pred_ridge = ridge.predict(x_test_scale)

# %%
r2_ridge = r2_score(y_test, y_pred_ridge)
r2_ridge*100
# Out:
# 90.03712806883485

# %% [markdown]
# # ElasticNet ( L12 )

# %%
elasticnet = ElasticNet()

# %%
elasticnet.fit(x_train_scale, y_train)
# Out:
# ElasticNet()

# %%
y_pred_elasticnet = elasticnet.predict(x_test_scale)

# %%
r2_elasticnet = r2_score(y_test, y_pred_elasticnet)
r2_elasticnet*100
# Out:
# 84.56226442653025
